# %% [markdown]
# ![bike1](https://img.freepik.com/vector-gratis/familia-andar-bicicleta-parque-ciudad_74855-5243.jpg?t=st=1729295981~exp=1729299581~hmac=f85ad2f10dca712c87ea2c98ec6efd0754c07665c989146050bfc6b27f0dd085&w=1380)

# %% [markdown]
# <h1 style="color:#000000; font-family:Arial, sans-serif; font-weight:bold; text-align:Left; font-size:26px;">
#     Case Study: Cyclistic - Google Data Analytics Professional Certificate
# </h1>
#
# <p style="font-size:14px; line-height:1.6; color:#333333;">
#     The bike-share company Cyclistic, based in Chicago, offers flexible pricing with single-ride, full-day, and annual passes. Customers who purchase single-ride or full-day passes are referred to as <strong style="color:#1a73e8;">Casual Riders</strong>. Customers who purchase annual memberships are <strong style="color:#FFA500;">Cyclistic Members</strong>. Annual members are more profitable, and the goal is to convert casual riders into members through targeted data analysis and marketing strategies. 🚴‍♂️
# </p>
# <p style="font-size:14px; line-height:1.6; color:#333333;">
#     The main objective of this project is to understand the differences in bike usage between <strong style="color:#1a73e8;">casual </strong>riders and <strong style="color:#FFA500;">members</strong> to develop strategies that encourage casual users to become members.
# </p>
# <h3 style="color:#000000; font-family:Arial, sans-serif; font-weight:bold; margin-top:18px; font-size:16px;">
#     Key Questions
# </h3>
#
# <ul style="font-size:14px; color:#333333; line-height:1.8; list-style-type:circle; margin-left:20px;">
#     <li>How do annual members and casual riders use Cyclistic bikes differently?</li>
#     <li>What factors could motivate casual riders to switch to annual memberships?</li>
#     <li>How can Cyclistic leverage this data to encourage casual riders to transition to annual memberships?</li>
# </ul>
#
# <h2 style="color:#000000; font-family:Arial, sans-serif; font-weight:bold; margin-top:18px; font-size:16px;">
#     Data-Driven Strategy
# </h2>
#
# <p style="font-size:14px; line-height:1.6; color:#333333;">
#     I will use python to explore key attributes within the dataset, create new features to gain insights into the main questions, and visualize significant attributes and relationships. Additionally, I will include interactive maps to show the most popular geographical locations based on bike user type.
# </p>
#
# <p style="font-size:14px; line-height:1.6; color:#333333;">
#     Visualizations and data-driven insights will guide the formulation of targeted marketing strategies to increase annual memberships.
# </p>
#
# <p style="font-size:14px; line-height:1.6; color:#333333;">
#     An interactive <a href="#TableauReport" style="color:#0072b1; text-decoration:none;">Tableau report</a> will also be provided to explore the data in greater detail.
# </p>

# %% [markdown]
# ***

# %% [markdown]
# ### **Shortcuts**
#
# <div style="border: 1px solid #e0e0e0; background-color: #e6f7ff; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
#   <h3><a href="#prepare-and-process-data" style="text-decoration: none; color: #0056b3;"><strong>Prepare and Process Data</strong></a></h3>
# </div>
#
# <div style="border: 1px solid #e0e0e0; background-color: #ffffe6; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
#   <h3><a href="#analyse-the-data" style="text-decoration: none; color: #0056b3;"><strong>Analysis using Python and Tableau</strong></a></h3>
# </div>
#
# <div style="border: 1px solid #e0e0e0; background-color: #e6ffe6; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
#   <h3><a href="#share-conclusions-and-insights" style="text-decoration: none; color: #0056b3;"><strong>Share Conclusions and Insights</strong></a></h3>
# </div>

# %% [markdown]
# ***

# %% [markdown]
# # <div style="text-align:center; border-radius:15px 50px; padding:30px; color:black; margin:10; font-size:120%; background-color:#a4d8f0; overflow:hidden"><b><strong><mark style="background-color:transparent;"></mark></strong></b>
# <a id="prepare-and-process-data"></a>

# %% [markdown]
# # **Step 1: Prepare and Process**

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #e6f7ff; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
#
# <h3 style="color:black;margin: 0;"><strong>Index</strong></h3>
#
# </div>

# %% [markdown]
#
# 1. [Change Column Data Type](#change-column-data-type)
#
# 2. [Identify and Remove Null Values](#identify-and-remove-null-values)
#
# 3. [Eliminate Unnecessary Columns](#eliminate-unnecessary-columns)
#
# 4. [Detect Duplicate Rows](#detect-duplicate-rows)
#
# 5. [Create New Features](#create-new-features)
#
# 6. [Ensure Data Adequacy & Define Ranges](#ensure-data-adequacy-and-define-ranges)
#
# 7. [Validate and Aggregate Data for Map Visualization](#validate-and-aggregate-data-for-map-visualization)
#
# 8. [Summary of Changes](#summary-of-changes)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import datetime
from datetime import timedelta  # time intervals

import math
from math import radians, sin, cos, sqrt, atan2 # distance calculations
import folium  # interactive maps

# %%
df_01 = pd.read_csv('datasets/202201-divvy-tripdata.csv')
df_02 = pd.read_csv('datasets/202202-divvy-tripdata.csv')
df_03 = pd.read_csv('datasets/202203-divvy-tripdata.csv')
df_04 = pd.read_csv('datasets/202204-divvy-tripdata.csv')
df_05 = pd.read_csv('datasets/202205-divvy-tripdata.csv')
df_06 = pd.read_csv('datasets/202206-divvy-tripdata.csv')
df_07 = pd.read_csv('datasets/202207-divvy-tripdata.csv')
df_08 = pd.read_csv('datasets/202208-divvy-tripdata.csv')
df_09 = pd.read_csv('datasets/202209-divvy-publictripdata.csv')
df_10 = pd.read_csv('datasets/202210-divvy-tripdata.csv')
df_11 = pd.read_csv('datasets/202211-divvy-tripdata.csv')
df_12 = pd.read_csv('datasets/202212-divvy-tripdata.csv')

# %%
all_df = [df_01, df_02, df_03, df_04, df_05, df_06, df_07, df_08, df_09, df_10, df_11, df_12]

df = pd.concat(objs=all_df, ignore_index=True)

df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  C2F7DD78E82EC875  electric_bike  2022-01-13 11:59:47  2022-01-13 12:02:44
# 1  A6CF8980A652D272  electric_bike  2022-01-10 08:41:56  2022-01-10 08:46:17
# 2  BD0F91DFF741C66D   classic_bike  2022-01-25 04:53:40  2022-01-25 04:58:01
# 3  CBB80ED419105406   classic_bike  2022-01-04 00:18:04  2022-01-04 00:33:00
# 4  DDC963BFDDA51EEA   classic_bike  2022-01-20 01:31:10  2022-01-20 01:37:12
#
#               start_station_name start_station_id  \
# 0       Glenwood Ave & Touhy Ave              525
# 1       Glenwood Ave & Touhy Ave              525
# 2  Sheffield Ave & Fullerton Ave     TA1306000016
# 3       Clark St & Bryn Mawr Ave     KA1504000151
# 4    Michigan Ave & Jackson Blvd     TA1309000002
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# 0           Clark St & Touhy Ave         RP-007  42.012800 -87.665906
# ...

# %%
df.tail()
# Out:
#                   ride_id  rideable_type           started_at  \
# 5667712  43ABEE85B6E15DCA   classic_bike  2022-12-05 06:51:04
# 5667713  F041C89A3D1F0270  electric_bike  2022-12-14 17:06:28
# 5667714  A2BECB88430BE156   classic_bike  2022-12-08 16:27:47
# 5667715  37B392960E566F58   classic_bike  2022-12-28 09:37:38
# 5667716  2DD1587210BA45AE   classic_bike  2022-12-09 00:27:25
#
#                     ended_at             start_station_name start_station_id  \
# 5667712  2022-12-05 06:54:48  Sangamon St & Washington Blvd            13409
# 5667713  2022-12-14 17:19:27        Bernard St & Elston Ave            18016
# 5667714  2022-12-08 16:32:20      Wacker Dr & Washington St     KA1503000072
# 5667715  2022-12-28 09:41:34  Sangamon St & Washington Blvd            13409
# 5667716  2022-12-09 00:35:28   Southport Ave & Waveland Ave            13235
#
#                  end_station_name end_station_id  start_lat  start_lng  \
# ...

# %%
df.shape
# Out:
# (5667717, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5667717 entries, 0 to 5667716
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: float64(4), object(9)
# memory usage: 562.1+ MB

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #e6f7ff; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
#   <ul style="color: #333; line-height: 1.6; font-family: Arial, sans-serif; padding-left: 20px">
#     <li>  The dataset is organized in a folder containing 12 CSV files, one for each month from January 2022 to December 2022.</li>
#     <li>  It is reliable, original, comprehensive, current, and correctly cited (ROCCC).</li>
#     <li>  There is no personal information about the riders.</li>
#     <li>  All files have consistent columns and values.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #e6f7ff; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
# <h3 style="color:black;margin: 0;"><strong>Change Column Data Type</strong></h3>
#
# <a id="change-column-data-type"></a>
#
# </div>

# %%
df['started_at']= pd.to_datetime(df['started_at'])

df['ended_at']= pd.to_datetime(df['ended_at'])

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #e6f7ff; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
# <h3 style="color:black;margin: 0;"><strong>Identify and Remove Null Values</strong></h3>
#
# <a id="identify-and-remove-null-values"></a>
#
# </div>

# %%
df.isna().sum()
# Out:
# ride_id                    0
# rideable_type              0
# started_at                 0
# ended_at                   0
# start_station_name    833064
# start_station_id      833064
# end_station_name      892742
# end_station_id        892742
# start_lat                  0
# start_lng                  0
# end_lat                 5858
# end_lng                 5858
# member_casual              0
# dtype: int64

# %% [markdown]
# - **Percentage of null values in columns**

# %%
(df.isna().sum())/df.shape[0]*100
# Out:
# ride_id                0.000000
# rideable_type          0.000000
# started_at             0.000000
# ended_at               0.000000
# start_station_name    14.698405
# start_station_id      14.698405
# end_station_name      15.751351
# end_station_id        15.751351
# start_lat              0.000000
# start_lng              0.000000
# end_lat                0.103357
# end_lng                0.103357
# member_casual          0.000000
# dtype: float64

# %% [markdown]
# - **Checking for null values using a heat map as a visualizing tool**

# %%
sns.set(rc={'figure.figsize':(8,5)})
sns.set_style('whitegrid')
sns.heatmap(df.isnull())
plt.show()

# %%
# Count null values in 'start station' and 'end station' for each month
null_start_station = df.groupby(df['started_at'].dt.to_period('M'))['start_station_name'].apply(lambda x: x.isnull().sum())
null_end_station = df.groupby(df['started_at'].dt.to_period('M'))['end_station_name'].apply(lambda x: x.isnull().sum())
null_start_stationid = df.groupby(df['started_at'].dt.to_period('M'))['start_station_id'].apply(lambda x: x.isnull().sum())
null_end_stationid = df.groupby(df['started_at'].dt.to_period('M'))['end_station_id'].apply(lambda x: x.isnull().sum())

# Create a DataFrame with null values per month
nulls_per_month = pd.DataFrame({'start_station_name': null_start_station, 'start_station_id': null_start_stationid, 'end_station_name': null_end_station, 'end_station_id': null_end_stationid})

# Create the bar chart
plt.figure(figsize=(12, 6))
nulls_per_month.plot(kind='bar', stacked=True, colormap='cividis', ax=plt.gca())
plt.xticks(rotation=45)
plt.xlabel('Month')
plt.ylabel('Number of Null Values')
plt.title('Number of Null Values per Month in Start Station (&ID) and End Station (&ID)')
plt.legend(title='Columns')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #e6f7ff; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
#   <ul style="color: #333; line-height: 1.6; font-family: Arial, sans-serif; padding-left: 20px">
#     <li>The null values chart by month follows the same trend as the trips chart by month, indicating that null values are not disproportionately present in any specific month. You can view the monthly chart next in this notebook or go there by clicking <a href="#monthly-chart">here</a>.
#  </li>
#   </ul>
# </div>

# %%
# Calculate the number of rows where exactly one entry is missing from at least one pair of station name & station id

df.loc[(df['start_station_id'].isna() ^ df['start_station_name'].isna()) \
  | (df['end_station_id'].isna() ^ df['end_station_name'].isna())].shape[0]
# Out:
# 0

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #e6f7ff; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
#   <ul style="color: #333; line-height: 1.6; font-family: Arial, sans-serif; padding-left: 20px">
#     <li>Station names and station IDs are missing in pairs, with no rows having only one missing entry. Consequently, we cannot recover the missing values by reference. </li>
#   </ul>
# </div>

# %%
# Count null values in 'start station' and 'end station' by biketype
null_start_station_rt = df.groupby(df['rideable_type'])['start_station_name'].apply(lambda x: x.isnull().sum())
null_end_station_rt = df.groupby(df['rideable_type'])['end_station_name'].apply(lambda x: x.isnull().sum())
null_start_stationid_rt = df.groupby(df['rideable_type'])['start_station_id'].apply(lambda x: x.isnull().sum())
null_end_stationid_rt = df.groupby(df['rideable_type'])['end_station_id'].apply(lambda x: x.isnull().sum())

# Create a DataFrame with null values per biketype
nulls_per_biketype = pd.DataFrame({'start_station_name': null_start_station_rt, 'start_station_id': null_start_stationid_rt, 'end_station_name': null_end_station_rt, 'end_station_id': null_end_stationid_rt})

# Create the bar chart
plt.figure(figsize=(10, 6))
nulls_per_biketype.plot(kind='bar', stacked=True, colormap='cividis', ax=plt.gca())
plt.xticks(rotation=45)
plt.xlabel('biketype')
plt.ylabel('Number of Null Values')
plt.title('Number of Null Values per biketype in Start Station (&ID) and End Station (&ID)')
plt.legend(title='Columns')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #e6f7ff; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
#   <ul style="color: #333; line-height: 1.6; font-family: Arial, sans-serif; padding-left: 20px">
#     <li>Null values are associated with electric bikes, which can be locked near a docking station, allowing trips to start or end outside designated stations. </li>
#     <li>These records should be retained, and I will label null values for electric bikes at station columns as 'not_at_station'.</li>
#   </ul>
# </div>

# %%
# Fill Null Station Names for Electric Bikes with "not_at_station"

df.loc[df['rideable_type'] == 'electric_bike', ['start_station_name', 'end_station_name', 'start_station_id', 'end_station_id']] = \
    df.loc[df['rideable_type'] == 'electric_bike', ['start_station_name', 'end_station_name', 'start_station_id', 'end_station_id']].fillna('not_at_station')

# %%
df.isna().sum()
# Out:
# ride_id                  0
# rideable_type            0
# started_at               0
# ended_at                 0
# start_station_name       0
# start_station_id         0
# end_station_name      6404
# end_station_id        6404
# start_lat                0
# start_lng                0
# end_lat               5858
# end_lng               5858
# member_casual            0
# dtype: int64

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #e6f7ff; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
#   <ul style="color: #333; line-height: 1.6; font-family: Arial, sans-serif; padding-left: 20px">
#     <li> Classic/docked bikes must be docked for security purposes, so having a null entry for these types of bikes would be misleading. </li>
#     <li> For all types of bikes, having null entries for start/end longitude and latitude would also be misleading. </li>
#     <li> Therefore, I will remove the remaining null values from the dataset. </li>
#   </ul>
# </div>

# %%
# Removing rows with Null lat and lng
df = df.dropna(subset=['start_lat', 'start_lng', 'end_lat', 'end_lng'])

# %%
df.isna().sum()
# Out:
# ride_id                 0
# rideable_type           0
# started_at              0
# ended_at                0
# start_station_name      0
# start_station_id        0
# end_station_name      546
# end_station_id        546
# start_lat               0
# start_lng               0
# end_lat                 0
# end_lng                 0
# member_casual           0
# dtype: int64

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #e6f7ff; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
#   <ul style="color: #333; line-height: 1.6; font-family: Arial, sans-serif; padding-left: 20px">
#     <li>There are 546 records without an end station registered, possibly due to loss, theft, or simple error.</li>
#   </ul>
# </div>

# %%
# Removing rows with null end station
df = df.dropna(subset=['end_station_name', 'end_station_id'])

# %%
df.isna().sum()
# Out:
# ride_id               0
# rideable_type         0
# started_at            0
# ended_at              0
# start_station_name    0
# start_station_id      0
# end_station_name      0
# end_station_id        0
# start_lat             0
# start_lng             0
# end_lat               0
# end_lng               0
# member_casual         0
# dtype: int64

# %%
df.shape
# Out:
# (5661313, 13)

# %% [markdown]
# ***

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #e6f7ff; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
# <h3 style="color:black;margin: 0;"><strong>Eliminate Unnecessary Columns</strong></h3>
#
# <a id="eliminate-unnecessary-columns"></a>
#
# </div>

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #e6f7ff; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
#   <ul style="color: #333; line-height: 1.6; font-family: Arial, sans-serif; padding-left: 20px">
#     <li>Since the station_id columns can't recover the null station names, these columns are not required for the analysis.</li>
#   </ul>
# </div>

# %%
# Dropping station ID columns
df.drop(['start_station_id', 'end_station_id'], axis=1, inplace=True)

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #e6f7ff; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
# <h3 style="color:black;margin: 0;"><strong>Detect Duplicate Rows</strong></h3>
#
# <a id="detect-duplicate-rows"></a>
#
# </div>

# %%
# Check for duplicate ride_id values
df['ride_id'].duplicated().sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div style="border: 1px solid #e0e0e0;background-color: #e6f7ff; padding: 20px; border-radius: 8px; margin-bottom: 10px;">
#   <ul style="color: #333; line-height: 1.6; font-family: Arial, sans-serif; padding-left: 20px">
#     <li>There are no duplicate rows in the dataset.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #e6f7ff; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
# <h3 style="color:black;margin: 0;"><strong>Create New Features</strong></h3>
#
# <a id="create-new-features"></a>
#
# </div>

# %% [markdown]
# - **Calculate ride duration**

# %%
df['duration_minutes'] = ((df['ended_at'] - df['started_at'])/pd.Timedelta(minutes=1)).astype('int32')

# %% [markdown]
# - **Start and End Location**

# %%
# Combining lat and lng for coordinates

df['start_loc'] = list(zip(df['start_lat'], df['start_lng']))
df['end_loc'] = list(zip(df['end_lat'], df['end_lng']))

# %% [markdown]
# -  **Distance between start and end stations**

# %%
# Function to calculate the distance between stations

def distance_formula(lat1, lon1, lat2, lon2):
    R = 6371  # Radius of the Earth in kilometers
    lat1, lon1, lat2, lon2 = radians(lat1), radians(lon1), radians(lat2), radians(lon2)

    dlat = lat2 - lat1
    dlon = lon2 - lon1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c
    return distance

# Create column
df['distance_km'] = np.vectorize(distance_formula)(
    df['start_lat'],
    df['start_lng'],
    df['end_lat'],
    df['end_lng'])

# %% [markdown]
# - **Month, Day and start Hour**

# %%
month_order = {1: 'January', 2: 'February', 3: 'March', 4: 'April', 5: 'May', 6: 'June', 
         7: 'July', 8: 'August', 9: 'September', 10: 'October', 11: 'November', 12: 'December'}

df['month'] = df['started_at'].dt.month.map(month_order)

df['day'] = df['started_at'].dt.day_name()

df['hour'] = df['started_at'].dt.hour

# %%
df.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  C2F7DD78E82EC875  electric_bike 2022-01-13 11:59:47 2022-01-13 12:02:44
# 1  A6CF8980A652D272  electric_bike 2022-01-10 08:41:56 2022-01-10 08:46:17
# 2  BD0F91DFF741C66D   classic_bike 2022-01-25 04:53:40 2022-01-25 04:58:01
# 3  CBB80ED419105406   classic_bike 2022-01-04 00:18:04 2022-01-04 00:33:00
# 4  DDC963BFDDA51EEA   classic_bike 2022-01-20 01:31:10 2022-01-20 01:37:12
#
#               start_station_name               end_station_name  start_lat  \
# 0       Glenwood Ave & Touhy Ave           Clark St & Touhy Ave  42.012800
# 1       Glenwood Ave & Touhy Ave           Clark St & Touhy Ave  42.012763
# 2  Sheffield Ave & Fullerton Ave  Greenview Ave & Fullerton Ave  41.925602
# 3       Clark St & Bryn Mawr Ave      Paulina St & Montrose Ave  41.983593
# 4    Michigan Ave & Jackson Blvd         State St & Randolph St  41.877850
#
# ...

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #e6f7ff; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
# <h3 style="color:black;margin: 0;"><strong>Ensure Data Adequacy & Define Ranges</strong></h3>
#
# <a id="ensure-data-adequacy-and-define-ranges"></a>
#
# </div>

# %%
print(df['rideable_type'].unique())
# Out:
# ['electric_bike' 'classic_bike' 'docked_bike']

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #e6f7ff; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
#   <ul style="color: #333; line-height: 1.6; font-family: Arial, sans-serif; padding-left: 20px">
#     <li> There are three types of 'rideable_type': electric_bike, classic_bike, and docked_bike.</li>
#     <li> Before April 2020, classic bikes were identified as docked_bikes. However, they must now be tracked as classic_bikes. </li>
#     <li> Therefore, 'docked_bike' is a naming error and should be updated to 'classic_bike'.</li>
#   </ul>
# </div>

# %%
# Create a dataframe for analyzing docked bikes

df_docked_bike = df.loc[df['rideable_type'] == 'docked_bike'].copy()

df_docked_bike.shape
# Out:
# (174858, 18)

# %%
# Changing docked bike to classic bike
df['rideable_type'] = df['rideable_type'].replace('docked_bike', 'classic_bike')
print(df['rideable_type'].unique())
# Out:
# ['electric_bike' 'classic_bike']

# %%
# Verifying that the numerical data falls within a realistic range
round(df.describe())
# Out:
#                           started_at                       ended_at  \
# count                        5661313                        5661313
# mean   2022-07-20 07:47:22.367847936  2022-07-20 08:03:39.647399936
# min              2022-01-01 00:00:05            2022-01-01 00:01:48
# 25%              2022-05-28 19:27:52            2022-05-28 19:47:42
# 50%              2022-07-22 15:18:48            2022-07-22 15:37:32
# 75%              2022-09-16 07:43:08            2022-09-16 07:56:08
# max              2022-12-31 23:59:26            2023-01-01 18:09:37
# std                              NaN                            NaN
#
#        start_lat  start_lng    end_lat    end_lng  duration_minutes  \
# count  5661313.0  5661313.0  5661313.0  5661313.0         5661313.0
# mean        42.0      -88.0       42.0      -88.0              16.0
# min         42.0      -88.0        0.0      -88.0          -10353.0
# 25%         42.0      -88.0       42.0      -88.0               5.0
# ...

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #e6f7ff; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
#   <ul style="color: #333; line-height: 1.6; font-family: Arial, sans-serif; padding-left: 20px">
#     <li> Since the distance represents the gap between the start and end stations, not the actual travel distance, a distance of 0 doesn't indicate an error; it just means the trip started and ended at the same station.</li>
#     <li> The maximum duration in minutes is excessively large.</li>
#     <li> The maximum distance is unusually high.</li>
#     <li> The minimum duration data is negative.</li>
#   </ul>
# </div>

# %%
# Rides with duration greater than a day
max_duration = df.query('duration_minutes > 1440')

# Rides with distance greater than 100 km
max_dist = df.query('distance_km > 100')

# Rides with duration less than a minute
neg_duration = df.query('duration_minutes < 1')

inadequate_data = pd.concat([max_duration, max_dist, neg_duration])

# %%
f"Percentage of rows with inadequeate data: {round((inadequate_data.shape[0]/df.shape[0])*100, 4)}%"
# Out:
# 'Percentage of rows with inadequeate data: 2.1417%'

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #e6f7ff; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
#   <ul style="color: #333; line-height: 1.6; font-family: Arial, sans-serif; padding-left: 20px">
#     <li> The percentage of rows with inadequate data is insignificant, so we can safely remove them from the dataset.</li>
#   </ul>
# </div>

# %%
# Deleting all rides with negative duration 
df = df.loc[df['duration_minutes'] >= 0]

# Deleting rides with duration greater than a day
df = df.loc[df['duration_minutes'] <= 1440]

# Deleting rides with distance greater than 100 km
df = df.loc[df['distance_km'] <= 100]

df.shape
# Out:
# (5661075, 18)

# %%
# Checking inadequate ride id
print(df.query('ride_id.str.len() != 16'))
# Out:
# Empty DataFrame
# Columns: [ride_id, rideable_type, started_at, ended_at, start_station_name, end_station_name, start_lat, start_lng, end_lat, end_lng, member_casual, duration_minutes, start_loc, end_loc, distance_km, month, day, hour]
# Index: []

# %% [markdown]
# ***

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #e6f7ff; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
# <h3 style="color:black;margin: 0;"><strong>Validate and Aggregate Data for Map Visualization</strong></h3>
#
# <a id="validate-and-aggregate-data-for-map-visualization"></a>
#
# </div>

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #e6f7ff; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
#   <ul style="color: #333; line-height: 1.6; font-family: Arial, sans-serif; padding-left: 20px">
#     <li> I will compile a comprehensive list of unique station names to verify the accuracy of their coordinates within the dataset.</li>
#     <li> Next, I will analyze rides for casual and member users separately to assess traffic frequencies for each group and create visual maps for comparison.</li>
#   </ul>
# </div>

# %%
# Dataframes of station names and station locations

start_station = df[['start_station_name', 'start_loc', 'member_casual']].copy()

end_station = df[['end_station_name', 'end_loc', 'member_casual']].copy()

# Renaming columns

start_station.rename(columns={'start_station_name': 'station_name', 'start_loc': 'station_loc'}, inplace=True)
end_station.rename(columns={'end_station_name': 'station_name', 'end_loc': 'station_loc'}, inplace=True)

# Exclude rows where start or end station is defined 'not_at_station'
start_station = start_station[start_station['station_name'] != 'not_at_station']
end_station = end_station[end_station['station_name'] != 'not_at_station']

# Combine the entries of start and end stations into a single DataFrame called all_station

all_station = pd.concat([start_station, end_station], ignore_index=True).reset_index(drop=True)

all_station
# Out:
#                           station_name  \
# 0             Glenwood Ave & Touhy Ave
# 1             Glenwood Ave & Touhy Ave
# 2        Sheffield Ave & Fullerton Ave
# 3             Clark St & Bryn Mawr Ave
# 4          Michigan Ave & Jackson Blvd
# ...                                ...
# 9602771       Peoria St & Jackson Blvd
# 9602772         Seeley Ave & Roscoe St
# 9602773          Green St & Madison St
# 9602774       Peoria St & Jackson Blvd
# 9602775         Seeley Ave & Roscoe St
#
#                                      station_loc member_casual
# 0                       (42.0128005, -87.665906)        casual
# 1                       (42.012763, -87.6659675)        casual
# 2                (41.9256018819, -87.6537080423)        member
# 3                        (41.983593, -87.669154)        casual
# 4                          (41.87785, -87.62408)        member
# ...                                          ...           ...
# ...

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #e6f7ff; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
#   <ul style="color: #333; line-height: 1.6; font-family: Arial, sans-serif; padding-left: 20px">
#     <li> There are numerous instances where slightly varying locations are assigned to the same station name.</li>
#   </ul>
# </div>

# %%
# Obtain the most common location and occurrence count per station for casual users

station_casual = all_station.query('member_casual == "casual"')\
                           .groupby('station_name')['station_loc']\
                           .agg([('station_loc', 'first'), ('occurrence', 'size')])\
                           .reset_index()\
                           .sort_values(by='occurrence', ascending=False)\
                           .reset_index(drop=True)

station_casual
# Out:
#                                            station_name  \
# 0                               Streeter Dr & Grand Ave
# 1                     DuSable Lake Shore Dr & Monroe St
# 2                                       Millennium Park
# 3                                 Michigan Ave & Oak St
# 4                    DuSable Lake Shore Dr & North Blvd
# ...                                                 ...
# 1659              Public Rack - Lotus Ave & Harrison St
# 1660                Public Rack - Longwood Dr & 95th St
# 1661  Public Rack - California Ave & Touhy Ave - mid...
# 1662                             Mackinaw Ave & 85th St
# 1663                                          Lowe Park
#
#                            station_loc  occurrence
# 0              (41.892278, -87.612043)      117725
# 1             (41.8810465, -87.616761)       61346
# 2           (41.8810317, -87.62408432)       52080
# 3          (41.90096039, -87.62377664)       51673
# ...

# %%
# Obtain the most common location and occurrence count per station for members

station_member = all_station.query('member_casual == "member"')\
                            .groupby('station_name')['station_loc']\
                            .agg([('station_loc', 'first'), ('occurrence', 'size')])\
                            .reset_index()\
                            .sort_values(by='occurrence', ascending=False)\
                            .reset_index(drop=True)

station_member
# Out:
#                          station_name                       station_loc  \
# 0            Kingsbury St & Kinzie St  (41.88917683258, -87.6385057718)
# 1                   Clark St & Elm St            (41.902973, -87.63128)
# 2               Wells St & Concord Ln           (41.912133, -87.634656)
# 3            University Ave & 57th St           (41.791478, -87.599861)
# 4        Clinton St & Washington Blvd             (41.88338, -87.64117)
# ...                               ...                               ...
# 1551     Pittsburgh Ave & Irving Park                   (41.95, -87.83)
# 1552                West Chatham Park                   (41.75, -87.63)
# 1553  Plainfield Ave & Irving Park Rd                   (41.95, -87.83)
# 1554          Princeton Ave & 43rd St                   (41.82, -87.63)
# 1555       New England Ave & Grace St                    (41.95, -87.8)
#
#       occurrence
# 0          49565
# 1          44388
# 2          43205
# 3          40475
# ...

# %% [markdown]
# ***

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #e6f7ff; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
#     <h3 style="color:black;margin: 0;"><strong>Summary of Changes</strong></h3>
# <a id="summary-of-changes"></a>
# </div>

# %% [markdown]
#    * The data types of columns containing datetime information have been corrected.
#
#    * Rows with null values have been analyzed and removed.
#
#    * Unnecessary columns have been removed from the analysis.
#
#    * The dataset has been verified to have no duplicate rows.
#
#    * New columns for duration, start location, end location, distance, hour, day, and month have been added.
#
#    * The dataframe has been validated to ensure realistic value ranges.
#
#    * Rows with inadequate data have been removed from the dataset.
#
#    * For map visualization, two new dataframes have been created separately for casual riders and members, containing unique station names, their locations, and their frequencies.

# %% [markdown]
# ***

# %% [markdown]
# # <div style="text-align:center; border-radius:15px 50px; padding:25px; color:Black; margin:0; font-size:120%; background-color:#ffe79a; overflow:hidden"><b><strong><mark style="background-color:transparent;"></mark></strong></b>
# <a id="analyse-the-data"></a>

# %% [markdown]
# # **Step 2: Analysis using Python and Tableau**

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #fff3cd; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
# <h3 style="color:black;margin: 0;"><strong>Index</strong></h3>
# </div>

# %% [markdown]
# 1. [Ride Count](#ride-count)
#
# 2. [Average Ride Duration](#average-ride-duration)
#
# 3. [Map Visualization of Popular Stations](#map-visualization-of-popular-stations)
#
# 4. [Distance between Start and End Stations](#distance-between-start-and-end-stations)
#
# 5. [Popular Routes](#popular-routes)
#
# 6. [Bike Type Usage](#bike-type-usage)
#
# 7. [Tableau and Power BI](#Tableau-report)

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #fff3cd; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
# <h3 style="color:black;margin: 0;"><strong>Ride Count</strong></h3>
# <a id="ride-count"></a>
# </div>

# %% [markdown]
# - In this section I will create visualizations to showcase the number of rides taken by Casual and Member users throughout the year, broken down by month, day, and hour.

# %%
agg = pd.DataFrame(df.groupby('member_casual')['duration_minutes']
                   .agg(['count', 'mean'])
                   .reset_index()
                   .rename(columns={'member_casual': 'user_type',
                                    'count': 'ride_count',
                                    'mean': 'mean_duration'}))

# Ride Count Pie Chart
fig, ax1 = plt.subplots(figsize=(6, 6))
ax1.set_title('Ride Count (2022)', fontsize=16, fontweight='bold')
ride_counts = agg['ride_count']
wedges, texts, autotexts = ax1.pie(ride_counts, labels=agg['user_type'], autopct='%1.0f%%',
                                   startangle=140, wedgeprops={'edgecolor': 'black'})
ax1.axis('equal')

legend_labels = [f"{agg['user_type'][i]}: {ride_counts[i]}" for i in range(len(agg))]
ax1.legend(wedges, legend_labels, loc="lower left", bbox_to_anchor=(-0.1, -0.12, 1, 1))
plt.tight_layout()
plt.show()

# %%
# Calculate ride counts by user type and day
week_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
ride_counts_day = df.groupby(['day', 'member_casual'])['member_casual'].count().unstack().loc[week_order]

# Daily Ride Counts
fig, ax2 = plt.subplots(figsize=(12, 8))
ride_counts_day.plot(kind='bar', ax=ax2, edgecolor='black')
ax2.set_title('Daily Ride Counts', fontsize=18, fontweight='bold')
ax2.set_xlabel('', fontsize=14)
ax2.set_ylabel('Ride Count', fontsize=14)
ax2.legend(fontsize=12, loc='upper right')
ax2.grid(axis='y', linestyle='--', alpha=0.7)
ax2.tick_params(axis='x', rotation=0)
plt.tight_layout()
plt.show()

# %%
# Calculate ride counts by user type and month
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
ride_counts_month = df.groupby(['month', 'member_casual'])['member_casual'].count().unstack().loc[month_order]

# Monthly Ride Counts
fig, ax3 = plt.subplots(figsize=(12, 8))
ride_counts_month.plot(kind='bar', ax=ax3, color=['#4c72b0', '#dd8452'], edgecolor='black')
ax3.set_title('Monthly Ride Counts', fontsize=18, fontweight='bold')
ax3.set_ylabel('Ride Count', fontsize=14)
ax3.set_xlabel('')
ax3.legend(fontsize=12)
ax3.grid(axis='y', linestyle='--', alpha=0.7)
ax3.tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.show()

# %%
# Ride Count by Hour
plt.figure(figsize=(12, 6))
sns.countplot(x='hour', hue='member_casual', data=df, edgecolor='black')
plt.title('Ride Count Across Hours', fontsize=16, fontweight='bold')
plt.xlabel('Hour', fontsize=14)
plt.ylabel('Ride Count', fontsize=14)
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **Insights**
#
# - Since we cannot distinguish each user, it's unclear whether members ride more frequently or if there are simply more member users than casual ones.
#
# **Daily Patterns:**
#
# - Members have higher ride counts on weekdays, while casual riders peak on weekends.
#
# - Member riders consistently have higher ride counts across all days of the week. Peaks are observed on Tuesday and Thursday, indicating a regular usage pattern, possibly linked to work commutes.
#
# - Casual riders have higher ride counts on Saturdays and Sundays, almost matching the counts of member riders on these days. This suggests that casual riders are more likely to use bikes for leisure or recreational activities during weekends.
#
# **Monthly Patterns:**
#
# - Both casual users and members show increased ride counts from January, peaking in July and August, and then decreasing towards December. This trend highlights the seasonal popularity of bike usage, likely due to better weather conditions during the summer and fall.
#
# **Hour Analysis:**
#
# - Evening hours show a lot of traffic compared to other times, largely due to the office timings of member riders.
#
# - Member usage peaks at 8 am (work start time) and 5 pm (end of workday).
#
# - Casual bike usage increases slightly throughout the day, peaking at 5 pm and then decreasing.

# %% [markdown]
# ***

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #fff3cd; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
# <h3 style="color:black;margin: 0;"><strong>Average Ride Duration</strong></h3>
#
# <a id="average-ride-duration"></a>
#
# </div>

# %%
# Calculate mean ride duration by user type and day
mean_duration_day = df.groupby(['day', 'member_casual'])['duration_minutes'].mean().unstack().loc[week_order]

# Aggregation
agg = pd.DataFrame(df.groupby('member_casual')['duration_minutes']
                   .agg(['count', 'mean'])
                   .reset_index()
                   .rename(columns={'member_casual': 'user_type',
                                    'count': 'ride_count',
                                    'mean': 'mean_duration'}))

# Create the first two plots in a horizontal layout
fig, axes = plt.subplots(1, 2, figsize=(24, 12))

# Plot 1: Total Mean Ride Duration
axes[0].set_title('Mean Ride Duration (minutes) \n ', fontsize=36, fontweight='bold')
sns.barplot(data=agg, x='user_type', y='mean_duration', ax=axes[0], edgecolor='black')
axes[0].set_xlabel('', fontsize=36)
axes[0].set_ylabel('Minutes', fontsize=30, va='bottom')
axes[0].tick_params(axis='x', labelsize=30)
axes[0].yaxis.set_label_coords(-0.05, 0.15)
for index, row in agg.iterrows():
    axes[0].text(index, row['mean_duration'] + 0.2, f"{row['mean_duration']:.1f}",
                 color='black', ha="center", fontsize=30)

# Plot 2: Daily Mean Ride Duration
mean_duration_day.plot(kind='bar', ax=axes[1], edgecolor='black')
axes[1].set_title('Daily Mean Ride Duration \n ', fontsize=36, fontweight='bold')
axes[1].set_xlabel('', fontsize=80)
axes[1].set_ylabel('Minutes', fontsize=30, va='bottom')
axes[1].tick_params(axis='x', labelsize=20)
axes[1].yaxis.set_label_coords(-0.04, 0.10)
axes[1].legend(fontsize=26, loc='upper center')
axes[1].grid(axis='y', linestyle='--', alpha=0.7)
axes[1].tick_params(axis='x', rotation=0)
for p in axes[1].patches:
    axes[1].annotate(f"{p.get_height():.1f}", (p.get_x() + p.get_width() / 2., p.get_height()),
                     ha='left', va='center', xytext=(0, 10), textcoords='offset points', fontsize=20)

plt.tight_layout()
plt.show()

# %%
# Calculate mean ride duration by user type and month
mean_duration_month = df.groupby(['month', 'member_casual'])['duration_minutes'].mean().unstack().loc[month_order]

# Plot 3: Monthly Mean Ride Duration
fig, ax = plt.subplots(figsize=(24, 12))
mean_duration_month.plot(kind='bar', ax=ax, color=['#4c72b0', '#dd8452'], edgecolor='black')
ax.set_title('Monthly Mean Ride Durations \n', fontsize=36, fontweight='bold')
ax.set_ylabel('Minutes', fontsize=30, va='bottom')
ax.yaxis.set_label_coords(-0.04, 0.10)
ax.set_xlabel('', fontsize=36)
ax.tick_params(axis='x', labelsize=30)
ax.legend(fontsize=26)
ax.grid(axis='y', linestyle='--', alpha=0.7)
ax.tick_params(axis='x', rotation=45)
for p in ax.patches:
    ax.annotate(f"{p.get_height():.0f}", (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=20)

plt.tight_layout()
plt.show()

# %% [markdown]
# <a id="monthly-chart"></a>

# %% [markdown]
# <a id="monthly-chart"></a>
# **Insights**
#
# - On average, Casual users take rides almost twice as long as Members.
#
# - Casual and member users’ average ride duration peaks on Saturdays and Sundays.
#
# - Casual riders' ride durations decrease by nearly half in December, likely due to colder temperatures, and gradually recover throughout January to peak in May.
#
# - In contrast, member riders' rides remain shorter and more consistent throughout the year, with a slight increase during the milder months.

# %% [markdown]
# ***

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #fff3cd; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
# <h3 style="color:black;margin: 0;"><strong>Map Visualization of Popular Stations</strong></h3>
#
# <a id="map-visualization-of-popular-stations"></a>
# </div>

# %% [markdown]
# - I will display the most popular stations among Casual riders and Members on two maps to identify any noticeable location trends.

# %% [markdown]
# #### **Top 10 Most Frequented Stations by Casual users**

# %%
# Calculate the mode and convert to float using iloc[0]
map_center = [float(df['start_lat'].mode().iloc[0]), float(df['start_lng'].mode().iloc[0])]
map1 = folium.Map(location=map_center, zoom_start=13)

# Calculate map bounds
bounds1 = [[station_casual['station_loc'].head(10).apply(lambda x: x[0]).min(), 
            station_casual['station_loc'].head(10).apply(lambda x: x[1]).min()],
           [station_casual['station_loc'].head(10).apply(lambda x: x[0]).max(), 
            station_casual['station_loc'].head(10).apply(lambda x: x[1]).max()]]

map1.fit_bounds(bounds=bounds1)

# Add markers and circle markers for top 10 most popular stations
for index, row in station_casual.head(10).iterrows():
    station_name = row['station_name']
    station_loc = row['station_loc']
    radius = row['occurrence'] / 1600
    folium.Marker(
        location=station_loc,
        popup=station_name,
        icon=folium.Icon(icon='bicycle', prefix='fa', color='blue')
    ).add_to(map1)
    folium.vector_layers.CircleMarker(
        location=station_loc,
        radius=radius,
        color='slateblue',
        fill_color='slateblue'
    ).add_to(map1)

map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Create the bar plot for casual users
plt.figure(figsize=(12, 8))
sns.barplot(x='occurrence', y='station_name', data=station_casual.head(10), palette='Blues_r')
plt.xlabel('Number of Visits')
plt.ylabel('Station Name')
plt.title('Top 10 Most Frequented Stations by Casual Users')
plt.show()

# %% [markdown]
# #### **Top 10 Most Frequented Stations by Members**

# %%
# Create a second map centered at the same location
map2 = folium.Map(location=map_center, zoom_start=13)

# Calculate map bounds for the second map
bounds2 = [[station_member['station_loc'].head(10).apply(lambda x: x[0]).min(), 
            station_member['station_loc'].head(10).apply(lambda x: x[1]).min()],
           [station_member['station_loc'].head(10).apply(lambda x: x[0]).max(), 
            station_member['station_loc'].head(10).apply(lambda x: x[1]).max()]]

map2.fit_bounds(bounds=bounds2)

# Add markers and circle markers for top 10 most popular stations in the second map
for index, row in station_member.head(10).iterrows():
    station_name = row['station_name']
    station_loc = row['station_loc']
    radius = row['occurrence'] / 1600
    folium.Marker(
        location=station_loc,
        popup=station_name,
        icon=folium.Icon(icon='bicycle', prefix='fa', color='orange')
    ).add_to(map2)
    folium.vector_layers.CircleMarker(
        location=station_loc,
        radius=radius,
        color='coral',
        fill_color='coral'
    ).add_to(map2)

map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Create the bar plot for members
plt.figure(figsize=(12, 8))
sns.barplot(x='occurrence', y='station_name', data=station_member.head(10), palette='Oranges_r')
plt.xlabel('Number of Visits')
plt.ylabel('Station Name')
plt.title('Top 10 Most Frequented Stations by Members')
plt.show()

# %% [markdown]
# **Insights**
#
#
# - The most popular stations for both casual riders and members are located in and around the main city area of Chicago.
#
# - However, stations frequented by casual riders are concentrated in the downtown area, near the port, parks, and tourist attractions of Chicago.
#
# - In contrast, stations favored by members are more dispersed.

# %% [markdown]
# ***

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #fff3cd; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
# <h3 style="color:black;margin: 0;"><strong>Distance between Start and End Stations</strong></h3>
# <a id="distance-between-start-and-end-stations"></a>
#
# </div>

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['distance_km'], bins=30, color='skyblue', edgecolor='black')
plt.xlabel('Distance (km)')
plt.ylabel('Frequency')
plt.title('Distribution of Distances between Stations')
plt.show()

# %%
average_distance_per_hour_member_casual = df.groupby(['hour', 'member_casual'])['distance_km'].mean().unstack()
plt.figure(figsize=(12, 6))
sns.heatmap(average_distance_per_hour_member_casual, cmap='YlGnBu')
plt.xlabel('Member Type')
plt.title('Average Distance per Hour of the Day by Member Type')
plt.ylabel('Hour of the Day')
plt.text(1.16, 0.5, 'Mean distance (km)', va='center', rotation=-90, fontsize=12, transform=plt.gca().transAxes)
plt.show()

# %% [markdown]
# **Insights**
#
# - The histogram depicts the frequency of distances (in kilometers) between start and end stations. The bars decrease in height from left to right, indicating that shorter distances are more common than longer ones.
#
# - The heatmap illustrates travel patterns between casual users and members. Casual users tend to travel longer distances during daytime hours, as shown by the darker shades in those time slots. Members exhibit more consistent travel behavior throughout the day, with slightly longer distances during the evening and early morning hours.

# %% [markdown]
# ***

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #fff3cd; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
# <h3 style="color:black;margin: 0;"><strong>Popular Routes</strong></h3>
# <a id="popular-routes"></a>
#
# </div>

# %%
# Filter rows where start_station_name or end_station_name are 'not_at_station'
df_station = df[(df['start_station_name'] != 'not_at_station') & (df['end_station_name'] != 'not_at_station')]

# Filter and group data by member type and routes
casual_routes = df_station[df_station['member_casual'] == 'casual'].groupby(['start_station_name', 'end_station_name']).agg({
    'ride_id': 'count',
    'distance_km': 'first'
}).reset_index()

member_routes = df_station[df_station['member_casual'] == 'member'].groupby(['start_station_name', 'end_station_name']).agg({
    'ride_id': 'count',
    'distance_km': 'first'
}).reset_index()

# Create route column
for routes_df in [casual_routes, member_routes]:
    routes_df['route'] = routes_df['start_station_name'] + ' --> ' + routes_df['end_station_name']

# Select top popular routes
top_casual_routes = casual_routes.sort_values(by='ride_id', ascending=False).head(15)
top_member_routes = member_routes.sort_values(by='ride_id', ascending=False).head(15)

# Plotting the most popular routes
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, sharey=False, figsize=(10,20))
sns.barplot(data=top_casual_routes, x='ride_id', y='route', ax=ax1, palette='Blues_r')
sns.barplot(data=top_member_routes, x='ride_id', y='route', ax=ax2, palette='YlOrBr_r')
ax1.set_title('Top 15 Popular Routes (Casual Riders) \n', fontsize=16, fontweight='bold')
ax1.set_xlabel('Number of Rides by Casual Riders', fontsize=14)
ax1.set_ylabel('Routes', fontsize=14)
ax2.set_title('Top 15 Popular Routes (Member Riders) \n', fontsize=16, fontweight='bold')
ax2.set_xlabel('Number of Rides by Member Riders', fontsize=14)
ax2.set_ylabel('Routes', fontsize=14)
plt.show()

# %% [markdown]
# **Insights**
#
# - Within Casual riders, the top favored routes are all situated in the Loop, Chicago's central business district.
#
# - Among Member riders, the top favored routes are around Ellis Ave. This area is home to the University of Chicago, indicating that university students frequently use bikes for campus travel.

# %% [markdown]
# ***

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #fff3cd; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
# <h3 style="color:black;margin: 0;"><strong>Bike Type Usage</strong></h3>
# <a id="bike-type-usage"></a>
#
# </div>

# %%
# Create figure and subplots
fig, (ax2, ax4) = plt.subplots(1, 2, figsize=(16, 8))

# Preparing data for the plots
ride_counts = df.groupby(['day', 'member_casual', 'rideable_type'])['rideable_type'].count().reset_index(name='count')

# Filter data for casual riders and members
ride_counts_casual = ride_counts[ride_counts['member_casual'] == 'casual']
ride_counts_member = ride_counts[ride_counts['member_casual'] == 'member']

# Plotting the daily ride counts by user type for casual riders
sns.barplot(data=ride_counts_casual, x='day', y='count', hue='rideable_type', order=week_order, ax=ax2, palette='Blues')
ax2.set_title('Casuals Daily Ride Counts by bike Type')
ax2.set_ylabel('Ride Count', labelpad=15, fontsize=12)
ax2.set_xlabel('')
ax2.legend(title='Rideable Type', loc='upper left', bbox_to_anchor=(0, 1))

# Plotting the daily ride counts by user type for members
sns.barplot(data=ride_counts_member, x='day', y='count', hue='rideable_type', order=week_order, ax=ax4, palette='Oranges')
ax4.set_title('Members Daily Ride Counts by bike Type')
ax4.set_ylabel('')
ax4.set_xlabel('')
ax4.legend(title='Rideable Type', bbox_to_anchor=(1, 1))

plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights**
#
# - Casual riders prefer electric bikes, while members favor classic bikes.
#
# - On weekends, classic bikes are more popular for both.

# %% [markdown]
# ***

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #fff3cd; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
# <h3 style="color:black;margin: 0;"><strong>Tableau Report</strong></h3>
# <a id="Tableau-report"></a>
# <a id="TableauReport"></a>
# </div>

# %%
from IPython.display import HTML

tableau_embed_code = """
<div class='tableauPlaceholder' id='viz1730415859691' style='position: relative'><noscript><a href='#'><img alt='    Cyclistic Analytics Dashboard ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Go&#47;GoogleCourseraCyclisticCase&#47;CyclisticAnalyticsDashboard&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='GoogleCourseraCyclisticCase&#47;CyclisticAnalyticsDashboard' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Go&#47;GoogleCourseraCyclisticCase&#47;CyclisticAnalyticsDashboard&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='es-ES' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1730415859691');                    var vizElement = divElement.getElementsByTagName('object')[0];                    if ( divElement.offsetWidth > 800 ) { vizElement.style.width='1200px';vizElement.style.height='827px';} else if ( divElement.offsetWidth > 500 ) { vizElement.style.width='1200px';vizElement.style.height='827px';} else { vizElement.style.width='100%';vizElement.style.height='2027px';}                     var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
"""
HTML(tableau_embed_code)
# Out:
# <div class='tableauPlaceholder' id='viz1730415859691' style='position: relative'><noscript><a href='#'><img alt='    Cyclistic Analytics Dashboard ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Go&#47;GoogleCourseraCyclisticCase&#47;CyclisticAnalyticsDashboard&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='GoogleCourseraCyclisticCase&#47;CyclisticAnalyticsDashboard' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Go&#47;GoogleCourseraCyclisticCase&#47;CyclisticAnalyticsDashboard&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' val
# ...

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #fff3cd; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
# <h3 style="color:black;margin: 0;"><strong>Power BI Report</strong></h3>
#
#
# </div>

# %%
from IPython.display import Image, display

display(Image(filename='../input/powerbipic/Cyclistic_Power_BI.jpg', width=1200))

# %% [markdown]
# ***

# %% [markdown]
# ## <div style="text-align:center; border-radius:15px 50px; padding:30px; color:Black; margin:0; font-size:120%; background-color:#ccffcc; overflow:hidden"><b><strong><mark style="background-color:transparent;"></mark></strong></b>
#
# <a id="share-conclusions-and-insights"></a>

# %% [markdown]
# # **Step 3: Share Conclusions and Insights**

# %% [markdown]
# ![bike4](https://img.freepik.com/vector-gratis/cuatro-ciclistas-montana-isometricos_1284-62568.jpg?t=st=1729296018~exp=1729299618~hmac=402cf16fc9113090a780eb6096da8cd1fddbcf2c8e3982645b21b6b43c2c9926&w=1380)

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #f9f9f9; padding: 20px; border-radius: 8px; font-family: Arial, sans-serif;">
#   <h2 style="text-align: left; font-size: 24px; color: #333;"><strong>Key Findings and Insights</strong></h2>
#   <table style="width:100%; border-collapse: collapse; text-align: left;">
#     <thead>
#       <tr>
#         <th style="font-size: 20px; color: #1F77B4; padding: 10px; border-bottom: 2px solid #ddd; background-color: #D9EAF7;">Casual Users</th>
#         <th style="font-size: 20px; color: #FF5733; padding: 10px; border-bottom: 2px solid #ddd; background-color: #FFE4CC;">Members</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#         <td style="color: black; padding: 10px; background-color: #D9EAF7;">- Higher ride counts on weekends.</td>
#         <td style="color: black; padding: 10px; background-color: #FFE4CC;">- Higher ride counts on weekdays, peaking on Tuesday and Thursday, indicating work commutes.</td>
#       </tr>
#       <tr>
#         <td style="color: black; padding: 10px; background-color: #D9EAF7;">- Usage increases throughout the day, peaking at 5 pm.</td>
#         <td style="color: black; padding: 10px; background-color: #FFE4CC;">- Usage peaks at 8 am and 5 pm.</td>
#       </tr>
#       <tr>
#         <td style="color: black; padding: 10px; background-color: #D9EAF7;">- Rides are almost twice as long as those of members.</td>
#         <td style="color: black; padding: 10px; background-color: #FFE4CC;">- Members show slight increases in warm months but remain relatively consistent throughout the year.</td>
#       </tr>
#       <tr>
#         <td style="color: black; padding: 10px; background-color: #D9EAF7;">- Tend to travel longer distances during the daytime.</td>
#         <td style="color: black; padding: 10px; background-color: #FFE4CC;">- Travel behavior remains steady with slightly longer distances in the evening and early morning.</td>
#       </tr>
#       <tr>
#         <td style="color: black; padding: 10px; background-color: #D9EAF7;">- Preferred stations concentrated downtown near ports, parks, and tourist attractions.</td>
#         <td style="color: black; padding: 10px; background-color: #FFE4CC;">- Preferred stations are more dispersed.</td>
#       </tr>
#       <tr>
#         <td style="color: black; padding: 10px; background-color: #D9EAF7;">- Top routes in the Loop, Chicago's central business district.</td>
#         <td style="color: black; padding: 10px; background-color: #FFE4CC;">- Top routes around Ellis Ave, likely due to the University of Chicago.</td>
#       </tr>
#       <tr>
#         <td style="color: black; padding: 10px; background-color: #D9EAF7;">- Prefer electric bikes.</td>
#         <td style="color: black; padding: 10px; background-color: #FFE4CC;">- Prefer classic bikes.</td>
#       </tr>
#     </tbody>
#   </table>
# </div>

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #f9f9f9; padding: 20px; border-radius: 8px; font-family: Arial, sans-serif;">
#   <h2 style="text-align: left; font-size: 24px; color: #333;"><strong>Recommendations and Strategies</strong></h2>
#
#   <table style="width: 100%; border-collapse: collapse;">
#     <thead>
#       <tr>
#         <th style="text-align: left; font-size: 20px; color: #0073e6; padding: 10px; background-color: #D9EAF7;">Casual Users</th>
#         <th style="text-align: left; font-size: 20px; color: #ff6600; padding: 10px; background-color: #FFE4CC;">Members</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#         <td style="padding: 10px; color: black; background-color: #D9EAF7;">
#           <strong>Weekend Offers:</strong> Create special weekend promotions or events to attract and convert casual riders to members.
#         </td>
#         <td style="padding: 10px; color: black; background-color: #FFE4CC;">
#           <strong>Weekday Promotions:</strong> Highlight membership benefits for regular commuters, focusing on weekday campaigns to engage casual riders.
#         </td>
#       </tr>
#       <tr>
#         <td style="padding: 10px; color: black; background-color: #D9EAF7;">
#           <strong>Peak Season Discounts:</strong> Run promotions during high-demand months (e.g., July, August) to entice casual users to become members.
#         </td>
#         <td style="padding: 10px; color: black; background-color: #FFE4CC;">
#           <strong>Winter Incentives:</strong> Offer seasonal discounts or perks to encourage members to continue biking in colder months.
#         </td>
#       </tr>
#       <tr>
#         <td style="padding: 10px; color: black; background-color: #D9EAF7;">
#           <strong>Convenience at Key Locations:</strong> Expand bike availability and offer discounts around recreational and tourist hotspots to increase weekend use.
#         </td>
#         <td style="padding: 10px; color: black; background-color: #FFE4CC;">
#           <strong>Loyalty Programs:</strong> Introduce loyalty rewards, special events, and priority access to popular stations to maintain member retention.
#         </td>
#       </tr>
#       <tr>
#         <td style="padding: 10px; color: black; background-color: #D9EAF7;">
#           <strong>Electric Bike Promotions:</strong> Since casual users prefer electric bikes, incentivize usage with special offers on e-bike rentals.
#         </td>
#         <td style="padding: 10px; color: black; background-color: #FFE4CC;">
#           <strong>Targeted Marketing:</strong> Use data on peak travel times to align promotions with member usage patterns, especially for commuter routes.
#         </td>
#       </tr>
#       <tr>
#         <td style="padding: 10px; color: black; background-color: #D9EAF7;">
#           <strong>Seasonal Memberships:</strong> Encourage casual users with flexible memberships or summer deals focused on frequent weekend riders.
#         </td>
#         <td style="padding: 10px; color: black; background-color: #FFE4CC;">
#           <strong>Exclusive Member Perks:</strong> Provide discounts at recreational venues, create an app for tracking rides, and integrate more benefits tied to member activities.
#         </td>
#       </tr>
#     </tbody>
#   </table>
# </div>

# %% [markdown]
# <div style="border: 1px solid #e0e0e0; background-color: #ccffcc; padding: 20px; border-radius: 8px; margin-bottom: 15px;">
# <h3 style="color:black;margin: 0;"><strong>Conclusion</strong></h3>
#  </div>

# %% [markdown]
# **Through a comprehensive and exhaustive analysis of the data**, we found that to effectively convert casual riders into annual members, Cyclistic should focus on promoting the convenience and cost-efficiency of membership for daily commuting. Additionally, launching special promotions during peak summer and fall seasons could further encourage casual riders to become members. By strategically highlighting popular stations and rideable types in marketing campaigns, Cyclistic can enhance user engagement and increase conversion rates. Aligning these strategies with our findings will contribute to building a more substantial base of loyal annual members.
#
#
# **Thank you for your time. If you found this notebook helpful, please consider upvoting and sharing your feedback!**
#
# [Kaggle](https://www.kaggle.com/martindambrosio) **|** [LinkedIn](https://www.linkedin.com/in/martin-german-dambrosio/)

# %% [markdown]
# ![bike2](https://img.freepik.com/vector-gratis/ciclismo-tour-conjunto-horizontal-ciclistas-equipamiento-deportivo-varias-posiciones-aisladas_1284-27912.jpg?t=st=1729295984~exp=1729299584~hmac=47b5a2b33468eb75c6742acc6588b3b7ba0e642200c9644ba7b2977cc4f18710&w=1480)
